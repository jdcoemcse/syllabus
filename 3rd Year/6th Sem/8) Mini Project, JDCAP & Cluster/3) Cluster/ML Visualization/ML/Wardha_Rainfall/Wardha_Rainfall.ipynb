# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Wardha_Dataset=pd.read_csv('Book12.csv',index_col='Date',parse_dates=True)

# %%
Wardha_Dataset
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2013-01-01             97.92              14.53              72.56      3.34
# 2013-01-02             98.00              13.31              71.38      2.34
# 2013-01-03             98.19               9.09              60.75      0.02
# 2013-01-04             98.12               8.42              56.50      0.00
# 2013-01-05             97.85               9.89              63.50      0.00
# ...                      ...                ...                ...       ...
# 2023-04-11             97.94               8.54              25.38      0.00
# 2023-04-12             97.86               8.30              22.94      0.00
# 2023-04-13             97.78               7.63              21.31      0.00
# 2023-04-14             97.78               8.54              26.75      0.00
# 2023-04-15             97.92              10.68              39.69      1.26
#
# ...

# %%
Wardha_Dataset.head(10)
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2013-01-01             97.92              14.53              72.56      3.34
# 2013-01-02             98.00              13.31              71.38      2.34
# 2013-01-03             98.19               9.09              60.75      0.02
# 2013-01-04             98.12               8.42              56.50      0.00
# 2013-01-05             97.85               9.89              63.50      0.00
# 2013-01-06             98.01               7.45              53.06      0.00
# 2013-01-07             98.22               5.98              46.81      0.00
# 2013-01-08             98.41               4.15              35.19      0.00
# 2013-01-09             98.40               4.46              36.12      0.00
# 2013-01-10             98.31               4.94              39.75      0.00
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# ...

# %%
Wardha_Dataset.tail(10)
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2023-04-06             97.78               6.47              20.94      0.00
# 2023-04-07             98.00               8.91              29.12      0.60
# 2023-04-08             98.29               9.77              36.75      0.20
# 2023-04-09             98.17               8.85              31.00      0.00
# 2023-04-10             98.03               8.97              29.25      0.00
# 2023-04-11             97.94               8.54              25.38      0.00
# 2023-04-12             97.86               8.30              22.94      0.00
# 2023-04-13             97.78               7.63              21.31      0.00
# 2023-04-14             97.78               8.54              26.75      0.00
# 2023-04-15             97.92              10.68              39.69      1.26
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# ...

# %%
Wardha_Dataset.shape
# Out:
# (3757, 8)

# %%
Wardha_Dataset.columns
# Out:
# Index(['Surface Pressure', 'Specific Humidity', 'Relative Humidity',
#        'Rainfall', 'Temperature', 'Temperature range', 'Temperature max',
#        'Temperature min'],
#       dtype='object')

# %%
Wardha_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3757 entries, 2013-01-01 to 2023-04-15
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Surface Pressure   3757 non-null   float64
#  1   Specific Humidity  3757 non-null   float64
#  2   Relative Humidity  3757 non-null   float64
#  3   Rainfall           3757 non-null   float64
#  4   Temperature        3757 non-null   float64
#  5   Temperature range  3757 non-null   float64
#  6   Temperature max    3757 non-null   float64
#  7   Temperature min    3757 non-null   float64
# dtypes: float64(8)
# memory usage: 264.2 KB

# %%
Wardha_Dataset.dtypes
# Out:
# Surface Pressure     float64
# Specific Humidity    float64
# Relative Humidity    float64
# Rainfall             float64
# Temperature          float64
# Temperature range    float64
# Temperature max      float64
# Temperature min      float64
# dtype: object

# %%
Wardha_Dataset.describe()
# Out:
#        Surface Pressure  Specific Humidity  Relative Humidity     Rainfall  \
# count       3757.000000        3757.000000        3757.000000  3757.000000
# mean          97.721443          12.108744          56.777418     3.062462
# std            0.524319           5.476480          25.620593     8.276325
# min           96.360000           1.830000           6.750000     0.000000
# 25%           97.270000           7.200000          31.380000     0.000000
# 50%           97.720000          11.170000          62.120000     0.010000
# 75%           98.190000          18.190000          81.060000     2.030000
# max           98.810000          21.550000          94.060000   114.900000
#
#        Temperature  Temperature range  Temperature max  Temperature min
# count  3757.000000        3757.000000      3757.000000      3757.000000
# mean     26.933609        -260.605552        33.487836        20.943005
# std       5.532024           4.758814         5.755535         5.907484
# ...

# %%
Wardha_Dataset.isnull().sum()
# Out:
# Surface Pressure     0
# Specific Humidity    0
# Relative Humidity    0
# Rainfall             0
# Temperature          0
# Temperature range    0
# Temperature max      0
# Temperature min      0
# dtype: int64

# %%
plt.hist(Wardha_Dataset['Temperature'])
# Out:
# (array([ 10.,  98., 464., 484., 874., 815., 288., 296., 313., 115.]),
#  array([12.3  , 15.153, 18.006, 20.859, 23.712, 26.565, 29.418, 32.271,
#         35.124, 37.977, 40.83 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (15,12))
sns.heatmap(Wardha_Dataset.corr(),annot = True )
# Out:
# <AxesSubplot: >

# %%
Wardha_Dataset['Surface Pressure'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
Wardha_Dataset['Specific Humidity'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
Wardha_Dataset['Rainfall'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
Wardha_Dataset['Temperature'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
Wardha_Dataset['Temperature min'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
Wardha_Dataset['Temperature max'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.plot(Wardha_Dataset['Temperature min'], label='Temperature min')
plt.plot(Wardha_Dataset['Temperature max'], label='Temperature max')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('Temperature Range')
plt.legend()
plt.savefig('Temperature_Range.png')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.plot(Wardha_Dataset['Specific Humidity'], label='Specific Humidity')
plt.plot(Wardha_Dataset['Relative Humidity'], label='Relative Humidity')
plt.xlabel('Date')
plt.ylabel('Humidity')
plt.title('Specific and Relative Humidity Comparison')
plt.savefig('Specific_and_Relative_Humidity.png')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Group temperature data by year
df_yearly = Wardha_Dataset.groupby(Wardha_Dataset.index.year)

# Create list of yearly temperatures for box plot
yearly_temps = [group[1]['Temperature'].values for group in df_yearly]

# Create box plot
plt.figure(figsize=(10, 6))
plt.boxplot(yearly_temps, labels=df_yearly.groups.keys())

# Set axis labels and title
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Distribution by Year')

# Show plot
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
      print("\t",key, ": ", val)

# %%
adf_test(Wardha_Dataset['Temperature'])
# Out:
# 1. ADF :  -5.095003356854605
# 2. P-Value :  1.4346969707367962e-05
# 3. Num Of Lags :  29
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 3727
# 5. Critical Values :
# 	 1% :  -3.4321057847086203
# 	 5% :  -2.862315808671018
# 	 10% :  -2.5671829738903393

# %%
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(Wardha_Dataset['Temperature'], 
                          suppress_warnings=True)           

stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 3757
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -5057.553
# Date:                Thu, 20 Apr 2023   AIC                          10127.106
# Time:                        12:38:08   BIC                          10164.494
# Sample:                    01-01-2013   HQIC                         10140.402
#                          - 04-15-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0906      0.025      3.634      0.000       0.042       0.139
# ar.L1          1.8435      0.039     47.834      0.000       1.768       1.919
# ar.L2         -1.1014      0.042    -26.037      0.000      -1.184      -1.019
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
print(Wardha_Dataset.shape)
train=Wardha_Dataset.iloc[:-30]
test=Wardha_Dataset.iloc[-30:]
print(train.shape,test.shape)
print(test.iloc[0],test.iloc[-1])
# Out:
# (3757, 8)
# (3727, 8) (30, 8)
# Surface Pressure      98.00
# Specific Humidity      9.83
# Relative Humidity     43.88
# Rainfall               0.85
# Temperature           27.02
# Temperature range   -264.70
# Temperature max       31.76
# Temperature min       23.30
# Name: 2023-03-17 00:00:00, dtype: float64 Surface Pressure      97.92
# Specific Humidity     10.68
# Relative Humidity     39.69
# Rainfall               1.26
# Temperature           30.58
# Temperature range   -260.70
# Temperature max       38.08
# Temperature min       25.63
# Name: 2023-04-15 00:00:00, dtype: float64

# %%
Wardha_Dataset=pd.read_csv('Book12.csv' , index_col='Date', parse_dates=True)
Wardha_Dataset=Wardha_Dataset.dropna()
print('Shape of data', Wardha_Dataset.shape)
Wardha_Dataset.head()
# Out:
# Shape of data (3757, 8)
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2013-01-01             97.92              14.53              72.56      3.34
# 2013-01-02             98.00              13.31              71.38      2.34
# 2013-01-03             98.19               9.09              60.75      0.02
# 2013-01-04             98.12               8.42              56.50      0.00
# 2013-01-05             97.85               9.89              63.50      0.00
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# 2013-01-01        25.30            -260.96            31.85            19.66
# 2013-01-02        24.11            -261.60            30.62            19.08
# 2013-01-03        20.80            -258.13            29.19            14.17
# 2013-01-04        20.07            -255.73            29.13            11.71
# 2013-01-05        21.42            -256.49            31.10            14.45

# %%
Wardha_Dataset['Rainfall'].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
    Wardha_Dataset = adfuller(dataset, autolag ='AIC')
    print("1. Surface Pressure : ", Wardha_Dataset[0])
    print("2. Specific Humidity : ", Wardha_Dataset[1]) 
    print("3. Relative Humidity  : ", Wardha_Dataset[2])
    print("4. Rainfall :", Wardha_Dataset[3])
    print("5. Temperature :")
    for key, val in Wardha_Dataset[4].items():
        print("\t",key, ": ", val)

# %%
ad_test(Wardha_Dataset['Rainfall'])
# Out:
# 1. Surface Pressure :  -6.151220436078456
# 2. Specific Humidity :  7.554134209299052e-08
# 3. Relative Humidity  :  28
# 4. Rainfall : 3728
# 5. Temperature :
# 	 1% :  -3.4321053134114368
# 	 5% :  -2.8623156004856782
# 	 10% :  -2.567182863059851

# %%
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(Wardha_Dataset['Rainfall'], trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=24933.815, Time=0.80 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=26544.984, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=25154.760, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=25428.249, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=27025.213, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=24937.605, Time=0.53 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=25150.139, Time=0.80 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=24934.592, Time=1.30 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=24934.921, Time=1.78 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=25154.218, Time=0.25 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=24933.192, Time=0.73 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=25224.806, Time=0.48 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=24934.655, Time=0.95 sec
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
print(Wardha_Dataset.shape)
train=Wardha_Dataset.iloc[:-30]
test=Wardha_Dataset.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (3757, 8)
# (3727, 8) (30, 8)

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train['Rainfall'], order=(9,0,8))
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:               Rainfall   No. Observations:                 3727
# Model:                 ARIMA(9, 0, 8)   Log Likelihood              -12363.887
# Date:                Thu, 20 Apr 2023   AIC                          24765.775
# Time:                        12:41:37   BIC                          24884.019
# Sample:                    01-01-2013   HQIC                         24807.840
#                          - 03-16-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0648      1.397      2.194      0.028       0.327       5.802
# ar.L1         -0.1586      0.362     -0.438      0.662      -0.869       0.551
# ar.L2         -0.2021      0.235     -0.861      0.389      -0.662       0.258
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels')
print(pred)
#pred.index=df.index[ start :end+2]
#print(pred)
# Out:
# 2023-03-17    0.888935
# 2023-03-18    0.898692
# 2023-03-19    0.936799
# 2023-03-20    0.989101
# 2023-03-21    1.063985
# 2023-03-22    1.089573
# 2023-03-23    1.136787
# 2023-03-24    1.201204
# 2023-03-25    1.260744
# 2023-03-26    1.306044
# 2023-03-27    1.346545
# 2023-03-28    1.396372
# 2023-03-29    1.434954
# 2023-03-30    1.494484
# 2023-03-31    1.535100
# 2023-04-01    1.568838
# 2023-04-02    1.604675
# 2023-04-03    1.654914
# 2023-04-04    1.696333
# 2023-04-05    1.726079
# 2023-04-06    1.764613
# 2023-04-07    1.796769
# 2023-04-08    1.835158
# 2023-04-09    1.869884
# 2023-04-10    1.904273
# 2023-04-11    1.928488
# 2023-04-12    1.960602
# 2023-04-13    1.996694
# 2023-04-14    2.024062
# 2023-04-15    2.050598
# Freq: D, Name: predicted_mean, dtype: float64

# %%
pred.plot(legend=True)
test['Temperature'].plot(legend=True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
plt.scatter(x='Temperature',y='Temperature')
plt.show()

# %%
test['Rainfall'].mean()
# Out:
# 0.205

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(pred, test['Rainfall']))
print(rmse)
# Out:
# 1.4972702368039141

# %%
model2=ARIMA(Wardha_Dataset['Rainfall'],order=(1,0,5))
model2=model2.fit()
Wardha_Dataset.tail()
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2023-04-11             97.94               8.54              25.38      0.00
# 2023-04-12             97.86               8.30              22.94      0.00
# 2023-04-13             97.78               7.63              21.31      0.00
# 2023-04-14             97.78               8.54              26.75      0.00
# 2023-04-15             97.92              10.68              39.69      1.26
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# 2023-04-11        34.93            -257.62            42.27            26.74
# 2023-04-12        35.80            -259.66            41.97            28.48
# 2023-04-13        35.69            -258.70            42.58            28.13
# 2023-04-14        34.08            -259.13            42.20            28.19
# 2023-04-15        30.58            -260.70            38.08            25.63

# %%
# create a list with 3757 elements
my_list = [i for i in range(3757)]

# create a list with a length of 31
my_axis = [0] * 31

# slice my_list to match the length of my_axis
my_list_sliced = my_list[:31]

# now you can assign my_list_sliced to my_axis without getting a length mismatch error
my_axis = my_list_sliced

# %%
pred.plot(figsize=(6, 6), legend=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # SARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time

# %%
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d')

# %%
#read data
Wardha_Dataset = pd.read_csv('Book12.csv', parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

# %%
#infer the frequency of the data
Wardha_Dataset = Wardha_Dataset.asfreq(pd.infer_freq(Wardha_Dataset.index))

# %%
start_date = datetime(2013, 1, 1)
end_date = datetime(2023, 4, 15)
lim_Wardha_Dataset = Wardha_Dataset[start_date:end_date]

# %%
Wardha_Dataset.info
# Out:
# <bound method DataFrame.info of             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2013-01-01             97.92              14.53              72.56      3.34
# 2013-01-02             98.00              13.31              71.38      2.34
# 2013-01-03             98.19               9.09              60.75      0.02
# 2013-01-04             98.12               8.42              56.50      0.00
# 2013-01-05             97.85               9.89              63.50      0.00
# ...                      ...                ...                ...       ...
# 2023-04-11             97.94               8.54              25.38      0.00
# 2023-04-12             97.86               8.30              22.94      0.00
# 2023-04-13             97.78               7.63              21.31      0.00
# 2023-04-14             97.78               8.54              26.75      0.00
# 2023-04-15             97.92              10.68              39.69      1.26
#
# ...

# %%
Wardha_Dataset.tail(5)
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2023-04-11             97.94               8.54              25.38      0.00
# 2023-04-12             97.86               8.30              22.94      0.00
# 2023-04-13             97.78               7.63              21.31      0.00
# 2023-04-14             97.78               8.54              26.75      0.00
# 2023-04-15             97.92              10.68              39.69      1.26
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# 2023-04-11        34.93            -257.62            42.27            26.74
# 2023-04-12        35.80            -259.66            41.97            28.48
# 2023-04-13        35.69            -258.70            42.58            28.13
# 2023-04-14        34.08            -259.13            42.20            28.19
# 2023-04-15        30.58            -260.70            38.08            25.63

# %%
Wardha_Dataset.head(5)
# Out:
#             Surface Pressure  Specific Humidity  Relative Humidity  Rainfall  \
# Date
# 2013-01-01             97.92              14.53              72.56      3.34
# 2013-01-02             98.00              13.31              71.38      2.34
# 2013-01-03             98.19               9.09              60.75      0.02
# 2013-01-04             98.12               8.42              56.50      0.00
# 2013-01-05             97.85               9.89              63.50      0.00
#
#             Temperature  Temperature range  Temperature max  Temperature min
# Date
# 2013-01-01        25.30            -260.96            31.85            19.66
# 2013-01-02        24.11            -261.60            30.62            19.08
# 2013-01-03        20.80            -258.13            29.19            14.17
# 2013-01-04        20.07            -255.73            29.13            11.71
# 2013-01-05        21.42            -256.49            31.10            14.45

# %%
start_date = datetime(2013,1,1)
end_date = datetime(2023,4,15)
lim_Wardha_Dataset = Wardha_Dataset[start_date:end_date]

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_Wardha_Dataset)
plt.title('Rainfall', fontsize=20)
plt.ylabel('Temperature', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
first_diff = lim_Wardha_Dataset.diff()[1:]

# %%
plt.figure(figsize=(14,7))
plt.plot(first_diff)
plt.title('Temperature', fontsize=20)
plt.ylabel('Temperature', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axhline(0, color='k', linestyle='--', alpha=0.2)

# %%
from statsmodels.tsa.stattools import acf
ts = pd.to_numeric(ts['Temperature'], errors='Rainfall')
first_diff = ts.diff().dropna()
acf_vals = acf(first_diff)
num_lags = 20
plt.bar(range(num_lags), acf_vals[:num_lags])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 from statsmodels.tsa.stattools import acf
# ----> 2 ts = pd.to_numeric(ts['Temperature'], errors='Rainfall')
#       3 first_diff = ts.diff().dropna()
#       4 acf_vals = acf(first_diff)
#
# NameError: name 'ts' is not defined
